# %% [markdown]
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">{"cells":\[{"metadata":{"trusted":true},"cell\_type":"code","source":"import
# numpy as np\\nimport pandas as pd\\nimport
# sklearn\\n","execution\_count":1,"outputs":\[\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"from
# sklearn.datasets import load\_boston\\ndf =
# load\_boston()\\n","execution\_count":2,"outputs":\[\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"df.keys()\\n","execution\_count":4,"outputs":\[{"output\_type":"execute\_result","execution\_count":4,"data":{"text/plain":"dict\_keys(\['data',
# 'target', 'feature\_names', 'DESCR',
# 'filename'\])"},"metadata":{}}\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"boston
# = pd.DataFrame(df.data,
# columns=df.feature\_names)\\nboston.head()\\n","execution\_count":6,"outputs":\[{"output\_type":"execute\_result","execution\_count":6,"data":{"text/plain":"
# CRIM ZN INDUS CHAS NOX RM AGE DIS RAD TAX \\\\\\n0 0.00632 18.0 2.31 0.0
# 0.538 6.575 65.2 4.0900 1.0 296.0 \\n1 0.02731 0.0 7.07 0.0 0.469 6.421
# 78.9 4.9671 2.0 242.0 \\n2 0.02729 0.0 7.07 0.0 0.469 7.185 61.1 4.9671
# 2.0 242.0 \\n3 0.03237 0.0 2.18 0.0 0.458 6.998 45.8 6.0622 3.0 222.0
# \\n4 0.06905 0.0 2.18 0.0 0.458 7.147 54.2 6.0622 3.0 222.0 \\n\\n
# PTRATIO B LSTAT \\n0 15.3 396.90 4.98 \\n1 17.8 396.90 9.14 \\n2 17.8
# 392.83 4.03 \\n3 18.7 394.63 2.94 \\n4 18.7 396.90 5.33
# ","text/html":"</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\\n\\n</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <table style="width:100%;">
# <colgroup>
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# <col style="width: 7%" />
# </colgroup>
# <tbody>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n \n \n \n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">CRIM</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">ZN</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">INDUS</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">CHAS</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">NOX</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">RM</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">AGE</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">DIS</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">RAD</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">TAX</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">PTRATIO</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">B</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">LSTAT</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n \n \n \n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.00632\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">18.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.31\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.538\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.575\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">65.2\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.0900\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">1.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">296.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">15.3\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">396.90\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.98\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">1</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.02731\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">7.07\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.469\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.421\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">78.9\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.9671\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">242.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">17.8\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">396.90\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">9.14\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.02729\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">7.07\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.469\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">7.185\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">61.1\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.9671\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">242.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">17.8\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">392.83\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.03\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">3</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.03237\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.18\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.458\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.998\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">45.8\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.0622\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">3.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">222.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">18.7\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">394.63\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.94\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.06905\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.18\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.458\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">7.147\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">54.2\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.0622\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">3.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">222.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">18.7\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">396.90\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">5.33\n \n \n</span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# </tbody>
# </table>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\\n</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">"},"metadata":{}}\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"boston\['MEDV'\]
# =
# df.target\\nboston.head()\\n","execution\_count":8,"outputs":\[{"output\_type":"execute\_result","execution\_count":8,"data":{"text/plain":"
# CRIM ZN INDUS CHAS NOX RM AGE DIS RAD TAX \\\\\\n0 0.00632 18.0 2.31 0.0
# 0.538 6.575 65.2 4.0900 1.0 296.0 \\n1 0.02731 0.0 7.07 0.0 0.469 6.421
# 78.9 4.9671 2.0 242.0 \\n2 0.02729 0.0 7.07 0.0 0.469 7.185 61.1 4.9671
# 2.0 242.0 \\n3 0.03237 0.0 2.18 0.0 0.458 6.998 45.8 6.0622 3.0 222.0
# \\n4 0.06905 0.0 2.18 0.0 0.458 7.147 54.2 6.0622 3.0 222.0 \\n\\n
# PTRATIO B LSTAT MEDV \\n0 15.3 396.90 4.98 24.0 \\n1 17.8 396.90 9.14
# 21.6 \\n2 17.8 392.83 4.03 34.7 \\n3 18.7 394.63 2.94 33.4 \\n4 18.7
# 396.90 5.33 36.2 ","text/html":"</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\\n\\n</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <table style="width:100%;">
# <colgroup>
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# </colgroup>
# <tbody>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n \n \n \n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">CRIM</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">ZN</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">INDUS</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">CHAS</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">NOX</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">RM</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">AGE</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">DIS</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">RAD</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">TAX</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">PTRATIO</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">B</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">LSTAT</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">MEDV</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n \n \n \n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.00632\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">18.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.31\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.538\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.575\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">65.2\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.0900\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">1.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">296.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">15.3\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">396.90\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.98\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">24.0\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">1</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.02731\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">7.07\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.469\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.421\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">78.9\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.9671\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">242.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">17.8\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">396.90\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">9.14\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">21.6\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.02729\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">7.07\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.469\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">7.185\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">61.1\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.9671\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">242.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">17.8\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">392.83\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4.03\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">34.7\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">3</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.03237\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.18\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.458\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.998\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">45.8\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.0622\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">3.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">222.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">18.7\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">394.63\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.94\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">33.4\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.06905\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2.18\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0.458\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">7.147\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">54.2\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">6.0622\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">3.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">222.0\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">18.7\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">396.90\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">5.33\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">36.2\n \n \n</span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# </tbody>
# </table>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\\n</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">"},"metadata":{}}\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"boston.isnull()\\n","execution\_count":9,"outputs":\[{"output\_type":"execute\_result","execution\_count":9,"data":{"text/plain":"
# CRIM ZN INDUS CHAS NOX RM AGE DIS RAD TAX \\\\\\n0 False False False
# False False False False False False False \\n1 False False False False
# False False False False False False \\n2 False False False False False
# False False False False False \\n3 False False False False False False
# False False False False \\n4 False False False False False False False
# False False False \\n.. ... ... ... ... ... ... ... ... ... ... \\n501
# False False False False False False False False False False \\n502 False
# False False False False False False False False False \\n503 False False
# False False False False False False False False \\n504 False False False
# False False False False False False False \\n505 False False False False
# False False False False False False \\n\\n PTRATIO B LSTAT MEDV \\n0
# False False False False \\n1 False False False False \\n2 False False
# False False \\n3 False False False False \\n4 False False False False
# \\n.. ... ... ... ... \\n501 False False False False \\n502 False False
# False False \\n503 False False False False \\n504 False False False
# False \\n505 False False False False \\n\\n\[506 rows x 14
# columns\]","text/html":"</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\\n\\n</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <table style="width:100%;">
# <colgroup>
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# <col style="width: 6%" />
# </colgroup>
# <tbody>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n \n \n \n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">CRIM</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">ZN</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">INDUS</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">CHAS</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">NOX</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">RM</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">AGE</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">DIS</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">RAD</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">TAX</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">PTRATIO</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">B</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">LSTAT</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">MEDV</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n \n \n \n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">0</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">1</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">2</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">3</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="font-family:SimSun;font-weight:bold;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">4</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">...</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">...\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">501</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">502</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">503</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="odd">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">504</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# <tr class="even">
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p>
# <p><strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-weight:bold;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;">505</span></strong><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\n </span><strong><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-weight:bold;font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></strong></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n </span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# <td><p><span style="mso-spacerun:&#39;yes&#39;;font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">False\n \n \n</span><span style="font-family:Calibri;mso-fareast-font-family:SimSun;mso-bidi-font-family:&#39;Times New Roman&#39;;
# font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span></p></td>
# </tr>
# </tbody>
# </table>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\\n</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;">506
# rows 脳 14 columns</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">\\n</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
#
# <span style="mso-spacerun:'yes';font-family:SimSun;font-size:12.0000pt;
# mso-font-kerning:0.0000pt;">"},"metadata":{}}\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"boston.isnull().sum()\\n","execution\_count":11,"outputs":\[{"output\_type":"execute\_result","execution\_count":11,"data":{"text/plain":"CRIM
# 0\\nZN 0\\nINDUS 0\\nCHAS 0\\nNOX 0\\nRM 0\\nAGE 0\\nDIS 0\\nRAD 0\\nTAX
# 0\\nPTRATIO 0\\nB 0\\nLSTAT 0\\nMEDV 0\\ndtype:
# int64"},"metadata":{}}\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"from
# sklearn.model\_selection import train\_test\_split\\n\\nX =
# boston.drop('MEDV', axis=1)\\nY = boston\['MEDV'\]\\n\\nX\_train,
# X\_test, Y\_train, Y\_test = train\_test\_split(X, Y, test\_size = 0.15,
# random\_state=5)\\n\\nprint(X\_train.shape)\\nprint(X\_test.shape)\\nprint(Y\_train.shape)\\nprint(Y\_test.shape)\\n","execution\_count":13,"outputs":\[{"output\_type":"stream","text":"(430,
# 13)\\n(76,
# 13)\\n(430,)\\n(76,)\\n","name":"stdout"}\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"from
# sklearn.linear\_model import LinearRegression\\nfrom sklearn.metrics
# import
# mean\_squared\_error","execution\_count":15,"outputs":\[\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"lin\_model
# = LinearRegression()\\n\\nlin\_model.fit(X\_train,
# Y\_train)","execution\_count":17,"outputs":\[{"output\_type":"execute\_result","execution\_count":17,"data":{"text/plain":"LinearRegression()"},"metadata":{}}\]},{"metadata":{"trusted":true},"cell\_type":"code","source":"y\_train\_predict
# = lin\_model.predict(X\_train)\\nrmse =
# (np.sqrt(mean\_squared\_error(Y\_train,
# y\_train\_predict)))\\n\\nprint(\\"The model performance for training
# set\\")\\nprint('RMSE is {}'.format(rmse))\\nprint(\\"\\\\n\\")\\n\\n\#
# on testing set\\ny\_test\_predict = lin\_model.predict(X\_test)\\nrmse =
# (np.sqrt(mean\_squared\_error(Y\_test,
# y\_test\_predict)))\\n\\nprint(\\"The model performance for testing
# set\\")\\nprint('RMSE is
# {}'.format(rmse))\\n","execution\_count":18,"outputs":\[{"output\_type":"stream","text":"The
# model performance for training set\\nRMSE is
# 4.710901797319796\\n\\n\\nThe model performance for testing set\\nRMSE
# is
# 4.687543527902972\\n","name":"stdout"}\]}\],"metadata":{"kernelspec":{"name":"python3","display\_name":"Python
# 3","language":"python"},"language\_info":{"name":"python","version":"3.6.13","mimetype":"text/x-python","codemirror\_mode":{"name":"ipython","version":3},"pygments\_lexer":"ipython3","nbconvert\_exporter":"python","file\_extension":".py"}},"nbformat":4,"nbformat\_minor":5}</span><span
# style="mso-spacerun:'yes';font-family:Calibri;mso-fareast-font-family:SimSun;
# mso-bidi-font-family:'Times New Roman';font-size:12.0000pt;mso-font-kerning:0.0000pt;"></span>
